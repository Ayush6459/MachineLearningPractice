# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

# %%
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
RESHAPED = 784

# %%
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# Normalize inputs to be within in [0, 1]. 
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# One-hot representation of the labels.
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %%
# Building the model.
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,input_shape=(RESHAPED,),name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,name='dense_layer_3', activation='softmax'))
# Summary of the model.
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model.
model.compile(optimizer='SGD',loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Training the model. 
model.fit(X_train, Y_train,batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 5s 108us/sample - loss: 1.7439 - accuracy: 0.4438 - val_loss: 0.9408 - val_accuracy: 0.8008
# Epoch 2/50
# 48000/48000 [==============================] - 4s 91us/sample - loss: 0.9287 - accuracy: 0.7200 - val_loss: 0.5378 - val_accuracy: 0.8719
# Epoch 3/50
# 48000/48000 [==============================] - 4s 80us/sample - loss: 0.6932 - accuracy: 0.7905 - val_loss: 0.4254 - val_accuracy: 0.8913
# Epoch 4/50
# 48000/48000 [==============================] - 4s 86us/sample - loss: 0.5925 - accuracy: 0.8235 - val_loss: 0.3696 - val_accuracy: 0.9008
# Epoch 5/50
# 48000/48000 [==============================] - 4s 81us/sample - loss: 0.5274 - accuracy: 0.8435 - val_loss: 0.3370 - val_accuracy: 0.9065
# Epoch 6/50
# 48000/48000 [==============================] - 4s 83us/sample - loss: 0.4870 - accuracy: 0.8561 - val_loss: 0.3134 - val_accuracy: 0.9113
# Epoch 7/50
# 48000/48000 [==============================] - 4s 85us/sample - loss: 0.4580 - accuracy: 0.8650 - val_loss: 0.2974 - val_accuracy: 0.9173
# Epoch 8/50
# 48000/48000 [==============================] - 4s 89us/sample - loss: 0.4308 - accuracy: 0.8737 - val_loss: 0.2828 - val_accuracy: 0.9199
# Epoch 9/50
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.4108 - accuracy: 0.8791 - val_loss: 0.2691 - val_accuracy: 0.9244
# Epoch 10/50
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3901 - accuracy: 0.8864 - val_loss: 0.2599 - val_accuracy: 0.9251
# Epoch 11/50
# 48000/48000 [==============================] - 4s 85us/sample - loss: 0.3777 - accuracy: 0.8912 - val_loss: 0.2500 - val_accuracy: 0.9275
# Epoch 12/50
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3643 - accuracy: 0.8936 - val_loss: 0.2407 - val_accuracy: 0.9302
# Epoch 13/50
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.3512 - accuracy: 0.8968 - val_loss: 0.2342 - val_accuracy: 0.9316
# Epoch 14/50
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.3396 - accuracy: 0.9010 - val_loss: 0.2271 - val_accuracy: 0.9333
# Epoch 15/50
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.3309 - accuracy: 0.9028 - val_loss: 0.2222 - val_accuracy: 0.9351
# Epoch 16/50
# 48000/48000 [==============================] - 4s 82us/sample - loss: 0.3209 - accuracy: 0.9065 - val_loss: 0.2149 - val_accuracy: 0.9377
# Epoch 17/50
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.3101 - accuracy: 0.9105 - val_loss: 0.2107 - val_accuracy: 0.9383
# Epoch 18/50
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.3064 - accuracy: 0.9107 - val_loss: 0.2061 - val_accuracy: 0.9402
# Epoch 19/50
# 48000/48000 [==============================] - 4s 80us/sample - loss: 0.2939 - accuracy: 0.9137 - val_loss: 0.2012 - val_accuracy: 0.9413
# Epoch 20/50
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.2920 - accuracy: 0.9161 - val_loss: 0.1960 - val_accuracy: 0.9429
# Epoch 21/50
# 48000/48000 [==============================] - 4s 81us/sample - loss: 0.2873 - accuracy: 0.9167 - val_loss: 0.1927 - val_accuracy: 0.9438
# Epoch 22/50
# 48000/48000 [==============================] - 5s 110us/sample - loss: 0.2785 - accuracy: 0.9193 - val_loss: 0.1878 - val_accuracy: 0.9456
# Epoch 23/50
# 48000/48000 [==============================] - 4s 90us/sample - loss: 0.2693 - accuracy: 0.9209 - val_loss: 0.1843 - val_accuracy: 0.9467
# Epoch 24/50
# 48000/48000 [==============================] - 4s 89us/sample - loss: 0.2675 - accuracy: 0.9222 - val_loss: 0.1812 - val_accuracy: 0.9475
# Epoch 25/50
# 48000/48000 [==============================] - 4s 82us/sample - loss: 0.2616 - accuracy: 0.9245 - val_loss: 0.1774 - val_accuracy: 0.9488
# Epoch 26/50
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.2570 - accuracy: 0.9258 - val_loss: 0.1740 - val_accuracy: 0.9507
# Epoch 27/50
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.2532 - accuracy: 0.9259 - val_loss: 0.1716 - val_accuracy: 0.9503
# Epoch 28/50
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2467 - accuracy: 0.9281 - val_loss: 0.1690 - val_accuracy: 0.9510
# Epoch 29/50
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2444 - accuracy: 0.9276 - val_loss: 0.1656 - val_accuracy: 0.9522
# Epoch 30/50
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.2400 - accuracy: 0.9300 - val_loss: 0.1632 - val_accuracy: 0.9525
# Epoch 31/50
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2340 - accuracy: 0.9329 - val_loss: 0.1609 - val_accuracy: 0.9535
# Epoch 32/50
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2297 - accuracy: 0.9320 - val_loss: 0.1586 - val_accuracy: 0.9536
# Epoch 33/50
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.2313 - accuracy: 0.9340 - val_loss: 0.1562 - val_accuracy: 0.9545
# Epoch 34/50
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.2246 - accuracy: 0.9343 - val_loss: 0.1545 - val_accuracy: 0.9548
# Epoch 35/50
# 48000/48000 [==============================] - 6s 115us/sample - loss: 0.2194 - accuracy: 0.9349 - val_loss: 0.1521 - val_accuracy: 0.9549
# Epoch 36/50
# 48000/48000 [==============================] - 5s 111us/sample - loss: 0.2203 - accuracy: 0.9361 - val_loss: 0.1505 - val_accuracy: 0.9553
# Epoch 37/50
# 48000/48000 [==============================] - 5s 103us/sample - loss: 0.2126 - accuracy: 0.9373 - val_loss: 0.1489 - val_accuracy: 0.9561
# Epoch 38/50
# 48000/48000 [==============================] - 5s 94us/sample - loss: 0.2116 - accuracy: 0.9380 - val_loss: 0.1463 - val_accuracy: 0.9557
# Epoch 39/50
# 48000/48000 [==============================] - 4s 91us/sample - loss: 0.2102 - accuracy: 0.9392 - val_loss: 0.1443 - val_accuracy: 0.9571
# Epoch 40/50
# 48000/48000 [==============================] - 4s 92us/sample - loss: 0.2078 - accuracy: 0.9392 - val_loss: 0.1427 - val_accuracy: 0.9577
# Epoch 41/50
# 48000/48000 [==============================] - 4s 90us/sample - loss: 0.2059 - accuracy: 0.9389 - val_loss: 0.1408 - val_accuracy: 0.9578
# Epoch 42/50
# 48000/48000 [==============================] - 4s 89us/sample - loss: 0.2010 - accuracy: 0.9412 - val_loss: 0.1401 - val_accuracy: 0.9584
# Epoch 43/50
# 48000/48000 [==============================] - 4s 91us/sample - loss: 0.1977 - accuracy: 0.9419 - val_loss: 0.1383 - val_accuracy: 0.9588
# Epoch 44/50
# 48000/48000 [==============================] - 5s 95us/sample - loss: 0.1963 - accuracy: 0.9429 - val_loss: 0.1366 - val_accuracy: 0.9594
# Epoch 45/50
# 48000/48000 [==============================] - 4s 89us/sample - loss: 0.1959 - accuracy: 0.9430 - val_loss: 0.1356 - val_accuracy: 0.9594
# Epoch 46/50
# 48000/48000 [==============================] - 5s 103us/sample - loss: 0.1887 - accuracy: 0.9451 - val_loss: 0.1337 - val_accuracy: 0.9602
# Epoch 47/50
# 48000/48000 [==============================] - 5s 99us/sample - loss: 0.1889 - accuracy: 0.9445 - val_loss: 0.1330 - val_accuracy: 0.9604
# Epoch 48/50
# 48000/48000 [==============================] - 5s 95us/sample - loss: 0.1854 - accuracy: 0.9454 - val_loss: 0.1311 - val_accuracy: 0.9607
# Epoch 49/50
# 48000/48000 [==============================] - 4s 92us/sample - loss: 0.1828 - accuracy: 0.9454 - val_loss: 0.1303 - val_accuracy: 0.9613
# Epoch 50/50
# 48000/48000 [==============================] - 5s 98us/sample - loss: 0.1857 - accuracy: 0.9449 - val_loss: 0.1282 - val_accuracy: 0.9616

# %%
#evaluate the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test accuracy: 0.9623
